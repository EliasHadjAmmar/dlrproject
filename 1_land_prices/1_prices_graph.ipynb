# %%
import geopandas as gpd

# %%
bremen = gpd.read_file("/Users/giovanafalcao/Desktop/GitHub/land_prices/Land_Prices_Neighborhood_Bremen.gpkg")
bremen.plot("Land_Value", legend=True)
# Out:
# <Axes: >

# %%
berlin = gpd.read_file("/Users/giovanafalcao/Desktop/GitHub/land_prices/Land_Prices_Neighborhood_Berlin.gpkg")
berlin.plot("Land_Value", legend=True)
# Out:
# <Axes: >

# %%
dresden = gpd.read_file("/Users/giovanafalcao/Desktop/GitHub/land_prices/Land_Prices_Neighborhood_Dresden.gpkg")
dresden.plot("Land_Value", legend=True)
# Out:
# <Axes: >

# %%
frankfurt = gpd.read_file("/Users/giovanafalcao/Desktop/GitHub/land_prices/Land_Prices_Neighborhood_Frankfurt_am_Main.gpkg")
frankfurt.plot("Land_Value", legend=True)
# Out:
# <Axes: >

# %%
koeln = gpd.read_file("/Users/giovanafalcao/Desktop/GitHub/land_prices/Land_Prices_Neighborhood_Köln.gpkg")
koeln.plot("Land_Value", legend=True)
# Out:
# <Axes: >
